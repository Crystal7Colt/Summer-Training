# %% [markdown]
# # Summer Training day 7

# %% [markdown]
# ## Pandas Basics

# %%
import pandas as pd
df=pd.read_csv("amazon.csv")
df.describe()

# %%
df.info()

# %%
df.duplicated().sum()
df.isnull().sum()

# %% [markdown]
# Use mode for catergorical+ordinal

# %% [markdown]
# Use mean if no outlier

# %% [markdown]
# Use median if outliers present
