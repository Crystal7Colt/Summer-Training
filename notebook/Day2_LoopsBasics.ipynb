# %% [markdown]
# # Summer Training day 2

# %% [markdown]
# ## Basic loops

# %%
for i in range (1,11):
    print(2*i)

# %%
for i in range (1,101):
    if i%2==0:
        print(i)

# %%
sum=0
for i in range(1,101):
    if i%2==0:
        sum=sum+i
print(sum)

# %%
sum=0
for i in range(1,101):
    if i%2!=0:
        sum=sum+i
print(sum)

# %%
fact=1
for i in range(1,6):
    fact = fact*i
print(fact)

# %%
max([13,30,40,1,51,20,44,23,33])

# %%
list =[13,30,40,1,51,20,44,23,33]
max=0
for i in list:
    if i>max:
        max=i
print(max)

# %%
sum =0
len=0
for i in list:
    sum+=i
    len+=1
print(sum/len)

# %%
while(True):
    marks = int(input("Enter the Marks"))
    if marks>100:
        break
    elif marks>80 and marks<100:
        print("grade A")
    elif marks>60 and marks<79:
        print("grade B")
    elif marks>50 and marks<59:
        print("grade C")
    else:
        print("Fail")

# %%
p=1000
t=3
r=10
n=1
si= p*t*(r/100)
ca = p * ((1+(r/100))**(t))
ci=ca-p
print(si)
print(ci)

# %%
vowel=0
for i in "apple ball cat" :
    if i in "aeiou":
        vowel+=1
print(vowel)

# %%
for i in range (1,7):
    print(i*"*")

# %%
for i in range(1,6):
    for j in range(5-i):
        print(" ",end="")
    for k in range((2*i)-1):
        print("*",end="")
    print()

# %%
for i in range(1,7,1):
    print(i*"*")
for i in range(5,0,-1):
    print(i*"*")

# %%
l1=["apple","ball","cat","rat"]
l2=["boys","girls","sunday"]
print(l1+l2)
